# %%
import sys; sys.path.insert(0, "input/chemistry")
from cond_curve import plot_phase_map, plot_condensation_curves
from pathlib import Path
# %load_ext autoreload
# %autoreload 2

# %%
plot_phase_map("input/chemistry/Bath(H4)", "ZnS(s,l)", log_T=False)
# Out:
# /project/diana8/cwirth/HELIOS/input/chemistry/cond_curve.py:339: UserWarning: Duplicate column 'Zn(s,l)' in input/chemistry/Bath(H4)/condensates_merged.dat — second occurrence renamed to 'Zn(s,l).1'. Only the first occurrence will be used.
#   cond_df  = parse_condensates(comp_dir / "condensates_merged.dat")
# <Axes: title={'center': 'Bath(H4) — ZnS(s,l)'}, xlabel='T (K)', ylabel='log₁₀ P (bar)'>

# %%
comps = [p for p in Path("input/chemistry").iterdir() if (p / "condensates_merged.dat").exists()]
plot_condensation_curves(comps, "FeS(s,l)", log_T=False)
# Out:
# /project/diana8/cwirth/HELIOS/input/chemistry/cond_curve.py:339: UserWarning: Duplicate column 'Zn(s,l)' in input/chemistry/R3/condensates_merged.dat — second occurrence renamed to 'Zn(s,l).1'. Only the first occurrence will be used.
#   cond_df  = parse_condensates(comp_dir / "condensates_merged.dat")
# /project/diana8/cwirth/HELIOS/input/chemistry/cond_curve.py:339: UserWarning: Duplicate column 'Zn(s,l)' in input/chemistry/Krymka(LL3)/condensates_merged.dat — second occurrence renamed to 'Zn(s,l).1'. Only the first occurrence will be used.
#   cond_df  = parse_condensates(comp_dir / "condensates_merged.dat")
# /project/diana8/cwirth/HELIOS/input/chemistry/cond_curve.py:339: UserWarning: Duplicate column 'Zn(s,l)' in input/chemistry/EL3/condensates_merged.dat — second occurrence renamed to 'Zn(s,l).1'. Only the first occurrence will be used.
#   cond_df  = parse_condensates(comp_dir / "condensates_merged.dat")
# ...
